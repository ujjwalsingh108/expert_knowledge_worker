# %% [markdown]
# ### EVALUATION OF RAG IMPLEMENTATION

# %%
from evaluation import test
from rich import print

# %%
tests = test.load_tests()

# %%
print(len(tests))
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
print(count)
# Out:
# Counter({
#     'direct_fact': 70,
#     'temporal': 20,
#     'comparative': 10,
#     'numerical': 10,
#     'relationship': 10,
#     'spanning': 20,
#     'holistic': 10
# })

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
print(evaluate_retrieval(example))
# Out:
# RetrievalEval(
#     mrr=0.16666666666666666,
#     ndcg=0.29420493957109245,
#     keywords_found=2,
#     total_keywords=3,
#     keyword_coverage=66.66666666666666
# )

# %%
eval, answer, chunks = evaluate_answer(example)

# %%
print(eval)
# Out:
# AnswerEval(
#     feedback="The generated answer correctly identifies the winner as Maxine but omits the last name 'Thompson',
# which is a minor inaccuracy. Overall, it is largely accurate, complete enough for the query, and fully relevant.",
#     accuracy=4.0,
#     completeness=4.0,
#     relevance=5.0
# )

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The generated answer correctly identifies the winner as Maxine but omits the last name 'Thompson', which is a minor
# inaccuracy. Overall, it is largely accurate, complete enough for the query, and fully relevant.
# 4.0
# 4.0
# 5.0
